# %% [markdown]
# # Phases 4 & 5 — Classification Model + Validation
#
# **Goal:** Train a binary classifier to detect outage state from traffic features.
# Then validate on held-out events and extend to additional counties.
#
# **Requires:** Feature-engineered data from Notebook 03.

# %%
import sys
sys.path.insert(0, "..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from src.models.train_classifier import (
    train_random_forest, train_xgboost,
    evaluate_model, get_feature_importance
)

# %%
print("⏳ Requires feature data from Notebook 03 — cannot run yet.")

# %% [markdown]
# ## Pipeline (when data is ready)
# 1. Load features from Notebook 03 output
# 2. Train/test split by event (hold out one event per county)
# 3. Train Random Forest baseline
# 4. Train XGBoost
# 5. Compare precision/recall/F1/AUC-ROC
# 6. Feature importance analysis
# 7. Spatial validation: do flagged intersections cluster in known outage footprints?
# 8. Extend to Mecklenburg and Hamilton counties
